# %%
from bokeh.io import output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
output_notebook()


def show_points_on_map(anchor_point, list_of_points):
    
    map_options = GMapOptions(lat=anchor_point[1], lng=anchor_point[0], map_type="roadmap", zoom=16)

    plot = GMapPlot(
        x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, title="Regensburg"
    )

    # make list out of vectors for plotting
    x_points = []
    y_points = []
    for vec in list_of_points:
        x_points.append(vec[0])
        y_points.append(vec[1])
        
    source = ColumnDataSource(
        data=dict(
            lon=x_points,
            lat=y_points,
        )
    )

    circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
    plot.add_glyph(source, circle)

    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
    # output_file("gmap_plot.html")

    show(plot)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="020ecb06-a410-4620-9d8e-09a33fac974a">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="3e58be46-9c91-4318-ab70-8fe348fa44d7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3e58be46-9c91-4318-ab70-8fe348fa44d7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3e58be46-9c91-4318-ab70-8fe348fa44d7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c6c5f173-c0b3-4156-9c0a-58a45bb0f7cf":{"roots":{"references":[{"attributes":{"plot":{"id":"d3e5c3b7-0a09-4b79-b51d-23c59e8f709f","type":"GMapPlot"}},"id":"94002232-0253-438e-8fa3-9ef55cb2ebf2","type":"PanTool"},{"attributes":{"callback":null,"column_names":["lon","lat"],"data":{"lat":[49.028654,49.028204],"lon":[12.062709,12.062414]}},"id":"3e30fd9f-bcf8-4134-859b-4ac2d74fce00","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3e30fd9f-bcf8-4134-859b-4ac2d74fce00","type":"ColumnDataSource"},"glyph":{"id":"ea8b04b7-4f5f-4671-b1eb-31355df9b3e8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f4c5db72-8585-4242-88ad-04b799430409","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d3e5c3b7-0a09-4b79-b51d-23c59e8f709f","type":"GMapPlot"}},"id":"af2225e0-31c1-4e97-a028-c5fca9dd02a2","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"69e604bd-5918-44b5-91df-43fdb70e7542","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bf58c42a-9395-401a-869c-96dff1ede6cf","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"ea8b04b7-4f5f-4671-b1eb-31355df9b3e8","type":"Circle"},{"attributes":{"map_options":{"lat":49.028654,"lng":12.062709,"map_type":"roadmap","zoom":16},"renderers":[{"id":"f4c5db72-8585-4242-88ad-04b799430409","type":"GlyphRenderer"},{"id":"bf58c42a-9395-401a-869c-96dff1ede6cf","type":"BoxAnnotation"}],"title":"Regensburg","tool_events":{"id":"585449fe-4673-4249-bc80-a73f7292a500","type":"ToolEvents"},"tools":[{"id":"94002232-0253-438e-8fa3-9ef55cb2ebf2","type":"PanTool"},{"id":"af2225e0-31c1-4e97-a028-c5fca9dd02a2","type":"WheelZoomTool"},{"id":"7ab86a4d-29ed-4cc4-b742-f397d102a742","type":"BoxSelectTool"}],"x_range":{"id":"69e604bd-5918-44b5-91df-43fdb70e7542","type":"DataRange1d"},"y_range":{"id":"681198bd-03c7-4aac-9881-df63ef4a9b5d","type":"DataRange1d"}},"id":"d3e5c3b7-0a09-4b79-b51d-23c59e8f709f","type":"GMapPlot"},{"attributes":{"callback":null,"overlay":{"id":"bf58c42a-9395-401a-869c-96dff1ede6cf","type":"BoxAnnotation"},"plot":{"id":"d3e5c3b7-0a09-4b79-b51d-23c59e8f709f","type":"GMapPlot"}},"id":"7ab86a4d-29ed-4cc4-b742-f397d102a742","type":"BoxSelectTool"},{"attributes":{},"id":"585449fe-4673-4249-bc80-a73f7292a500","type":"ToolEvents"},{"attributes":{"callback":null},"id":"681198bd-03c7-4aac-9881-df63ef4a9b5d","type":"DataRange1d"}],"root_ids":["d3e5c3b7-0a09-4b79-b51d-23c59e8f709f"]},"title":"Bokeh Application","version":"0.11.1"}};
#             var render_items = [{"docid":"c6c5f173-c0b3-4156-9c0a-58a45bb0f7cf","elementid":"3e58be46-9c91-4318-ab70-8fe348fa44d7","modelid":"d3e5c3b7-0a09-4b79-b51d-23c59e8f709f","notebook_comms_target":"c8ac8c5e-0c37-4073-88b0-bc3a78ec7e70"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[1]</strong>&gt;</code></p>
