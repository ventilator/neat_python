# %%
import numpy as np
import math
np.set_printoptions(precision=3)
# prints _very_ small numbers (floating point errors)as 0
np.set_printoptions(suppress=True) 

# for plotting
from ipywidgets import interact
from bokeh.io import push_notebook, output_notebook, show
from bokeh.plotting import figure, show, output_notebook, output_file
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Segment, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
output_notebook()

router_names = ["pacwoman", "spooky", "toc-man", "spunky", "tim", "orson", "noname", "pinky", "blinky", "clyde", "inky"]

def construct_n_edge(n):
    startpoint = np.array([0,0])   
    unit_vec = np.array([1,0])
    angle = 2*math.pi / n
    rotation_matrix = np.array([[math.cos(angle), -math.sin(angle)], 
                               [math.sin(angle),  math.cos(angle)]])
    # built n-edge
    n_edge = []
    rotated_vector = unit_vec
    for i in range(n):
        rotated_vector = rotation_matrix.dot(rotated_vector)
        n_edge.append(rotated_vector)

    return n_edge
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bb6c5c16-565e-420d-a0fe-234e422ffade">Loading BokehJS ...</span>
#     </div>

# %%
def plot_n_edge(n_edge):
    x = []
    y = []
    
    # append first vector after last to close the circle (plotting detail)
    n_edge.append(n_edge[0])
    # rearrange vectors in x,y list
    for vec in n_edge:
        x.append(vec[0])
        y.append(vec[1])
        
    def plot(x,y): 
        p = figure(title="dots", plot_height=300, plot_width=300)
        r = p.line(x, y, color="#2222aa", line_width=3)
        x_text, y_text = zip(*n_edge)
        p.text(x_text, y_text, router_names[:len(x)-1], text_color="#333333", text_align="center", text_font_size="10pt")
        show(p)
        
    plot(x,y)    

# test generating and plotting
for n in range(3,9):
    n_edge = construct_n_edge(n)  
    plot_n_edge(n_edge)
# Out:
#     <div class="plotdiv" id="9186cd31-25b4-4edb-93d9-f02af2768d9b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9186cd31-25b4-4edb-93d9-f02af2768d9b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9186cd31-25b4-4edb-93d9-f02af2768d9b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1027ae6b-1e05-4185-b849-f8e542eb2a9f":{"roots":{"references":[{"attributes":{},"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3046197e-a163-4805-9573-652507f99035","subtype":"Figure","type":"Plot"}},"id":"f8623eb8-f68f-4772-86b9-4a2eed96aaf4","type":"HelpTool"},{"attributes":{"plot":{"id":"5f7a9bcd-a2e4-4e60-8705-fbc21f08128b","subtype":"Figure","type":"Plot"}},"id":"0ab5a2cb-d37b-4b5a-bc04-44b0d2abd626","type":"ResetTool"},{"attributes":{"formatter":{"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},"plot":{"id":"03c4b73f-c0ec-434e-b4f2-6414d404f08c","subtype":"Figure","type":"Plot"},"ticker":{"id":"1dbc3058-4057-4640-aa7e-3889dc341f4c","type":"BasicTicker"}},"id":"beec01d5-6355-405d-8078-8c73ce283342","type":"LinearAxis"},{"attributes":{},"id":"a7b799da-48ac-444f-964e-245fdad251cf","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"b289f8d3-ae1d-49fc-9dcf-f948bad425ca","type":"BoxAnnotation"},"plot":{"id":"37e1a327-cbfe-4c1f-8969-370168ad9a7c","subtype":"Figure","type":"Plot"}},"id":"85f6509c-e34f-44a5-b9ef-b2af73a0bd4d","type":"BoxZoomTool"},{"attributes":{},"id":"782c5a55-eff7-4fc6-828e-62aa6e9504b8","type":"BasicTickFormatter"},{"attributes":{},"id":"1e6d640b-f39f-4e5e-802a-d4928db6ca5c","type":"ToolEvents"},{"attributes":{},"id":"4bc62f89-e60d-435e-af5c-066b71faca04","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":
type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["text","x","y"],"data":{"text":["pacwoman","spooky","toc-man","spunky","tim","orson","noname","pinky","blinky","clyde","inky"],"x":[0.5000000000000001,-0.4999999999999998,-1.0,-0.5000000000000004,0.4999999999999994,1.0,0.5000000000000001],"y":[0.8660254037844386,0.8660254037844388,3.885780586188048e-16,-0.8660254037844384,-0.86602540 ...
#     <div class="plotdiv" id="1e01d2f6-f0f0-4a0a-a813-e45eaf7ea1e1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e01d2f6-f0f0-4a0a-a813-e45eaf7ea1e1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e01d2f6-f0f0-4a0a-a813-e45eaf7ea1e1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3debde7a-fce6-401e-bdbc-ef10cd2d8aae":{"roots":{"references":[{"attributes":{},"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3046197e-a163-4805-9573-652507f99035","subtype":"Figure","type":"Plot"}},"id":"f8623eb8-f68f-4772-86b9-4a2eed96aaf4","type":"HelpTool"},{"attributes":{"plot":{"id":"5f7a9bcd-a2e4-4e60-8705-fbc21f08128b","subtype":"Figure","type":"Plot"}},"id":"0ab5a2cb-d37b-4b5a-bc04-44b0d2abd626","type":"ResetTool"},{"attributes":{"formatter":{"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},"plot":{"id":"03c4b73f-c0ec-434e-b4f2-6414d404f08c","subtype":"Figure","type":"Plot"},"ticker":{"id":"1dbc3058-4057-4640-aa7e-3889dc341f4c","type":"BasicTicker"}},"id":"beec01d5-6355-405d-8078-8c73ce283342","type":"LinearAxis"},{"attributes":{},"id":"a7b799da-48ac-444f-964e-245fdad251cf","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"b289f8d3-ae1d-49fc-9dcf-f948bad425ca","type":"BoxAnnotation"},"plot":{"id":"37e1a327-cbfe-4c1f-8969-370168ad9a7c","subtype":"Figure","type":"Plot"}},"id":"85f6509c-e34f-44a5-b9ef-b2af73a0bd4d","type":"BoxZoomTool"},{"attributes":{},"id":"782c5a55-eff7-4fc6-828e-62aa6e9504b8","type":"BasicTickFormatter"},{"attributes":{},"id":"1e6d640b-f39f-4e5e-802a-d4928db6ca5c","type":"ToolEvents"},{"attributes":{},"id":"4bc62f89-e60d-435e-af5c-066b71faca04","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"a5bcafda-39b2-42b0-9993-066de8736c39","type":"BasicTickFormatter"},"plot":{"id":"c70fbdc1-6ec0-4af5-831a-faa7908e19ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf8b6649-e7b8-41f1-b2af-328e108922bd","type":"BasicTicker"}},"id":"201755dd-0b4f-430b-9988-ca3a7598330b","type":"LinearAxis"},{"attributes":{"plot":{"id":"aa116af7-068b-4fd6-8a1d-c6979addcaaf","subtype":"Figure","type":"Plot"},"ticker":{"id":"deb0f25d-1651-4d06-a211-536aa1cc47fa","type":"BasicTicker"}},"id":"5acbf516-1aff-4200-81fa-165d4b428a14","type":"Grid"},{"attributes":{"overlay":{"id":"1ac20f6a-8cdb-4d00-a472-6c905c01215e","type":"BoxAnnotation"},"plot":{"id":"87596c3e-f605-4ab2-9020-292a6d3e8558","subtype":"Figure","type":"Plot"}},"id":"e3020a6c-5fb8-4260-bd92-e911d191f0e5","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cf880c01-7498-4b7f-926c-7185c7813af2","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"a742695e-7b86-495b-80ef-4761e46b3416","type":"ColumnDataSource"},"glyph":{"id":"f473bad9-3dad-4ccf-896e-0aa761e6e554","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":
type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"a5bcafda-39b2-42b0-9993-066de8736c39","type":"BasicTickFormatter"},"plot":{"id":"c70fbdc1-6ec0-4af5-831a-faa7908e19ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf8b6649-e7b8-41f1-b2af-328e108922bd","type":"BasicTicker"}},"id":"201755dd-0b4f-430b-9988-ca3a7598330b","type":"LinearAxis"},{"attributes":{"plot":{"id":"aa116af7-068b-4fd6-8a1d-c6979addcaaf","subtype":"Figure","type":"Plot"},"ticker":{"id":"deb0f25d-1651-4d06-a211-536aa1cc47fa","type":"BasicTicker"}},"id":"5acbf516-1aff-4200-81fa-165d4b428a14","type":"Grid"},{"attributes":{"overlay":{"id":"1ac20f6a-8cdb-4d00-a472-6c905c01215e","type":"BoxAnnotation"},"plot":{"id":"87596c3e-f605-4ab2-9020-292a6d3e8558","subtype":"Figure","type":"Plot"}},"id":"e3020a6c-5fb8-4260-bd92-e911d191f0e5","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cf880c01-7498-4b7f-926c-7185c7813af2","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"a742695e-7b86-495b-80ef-4761e46b3416","type":"ColumnDataSource"},"glyph":{"id":"f473bad9-3dad-4ccf-896e-0aa761e6e554","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"884abaf3-afbf-4658-a51d-97efb14f07b5","type":"Text"},"selection_glyph":null},"id":"b8dc8a30-dae9-4289-9e12-f48cc4346d46","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"4aefa920-dff6-4deb-9448-6cc0bbe1128b","type":"ColumnDataSource"},"glyph":{"id":"bddde9f9-d73c-41a6-bd93-95c7de10e7c6","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"487f1a6a-193c-483e-a7a3-f92474c60e50","type":"Text"},"selection_glyph":null},"id":"3be9f0d5-bd37-4aa1-a188-0247642b3256","type":"GlyphRenderer"},{"attributes":{},"id":"74188be7-c5ae-4402-9d8f-db9d316efa9c","type":"BasicTicker"},{"attributes":{},"id":"2d1e3612-af95-4701-ba4d-529dd9010d7d","type":"ToolEvents"},{"attributes":{},"id":"e88a36bf-b619-4c85-b873-9eb88f872206","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["text","x","y"],"data":{"text":["pacwoman","spooky","toc-man","spunky","tim","orson","noname","pinky","blinky","clyde","inky"],"x":[0.5000000000000001,-0.4999999999999998,-1.0,-0.5000000000000004,0.4999999999999994,1.0,0.5000000000000001 ...
#     <div class="plotdiv" id="55be77ab-c07e-435d-a992-c2ba77edab90"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55be77ab-c07e-435d-a992-c2ba77edab90");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55be77ab-c07e-435d-a992-c2ba77edab90' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"adc8f252-9bba-4584-a960-d9bedce98f93":{"roots":{"references":[{"attributes":{},"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3046197e-a163-4805-9573-652507f99035","subtype":"Figure","type":"Plot"}},"id":"f8623eb8-f68f-4772-86b9-4a2eed96aaf4","type":"HelpTool"},{"attributes":{"callback":null},"id":"9af6ccc6-3459-44e3-9daf-2247ea002d4f","type":"DataRange1d"},{"attributes":{"plot":{"id":"5f7a9bcd-a2e4-4e60-8705-fbc21f08128b","subtype":"Figure","type":"Plot"}},"id":"0ab5a2cb-d37b-4b5a-bc04-44b0d2abd626","type":"ResetTool"},{"attributes":{"formatter":{"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},"plot":{"id":"03c4b73f-c0ec-434e-b4f2-6414d404f08c","subtype":"Figure","type":"Plot"},"ticker":{"id":"1dbc3058-4057-4640-aa7e-3889dc341f4c","type":"BasicTicker"}},"id":"beec01d5-6355-405d-8078-8c73ce283342","type":"LinearAxis"},{"attributes":{},"id":"a7b799da-48ac-444f-964e-245fdad251cf","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":
' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"39b4a58b-16aa-4a16-8e0f-ed826f2bfb6d":{"roots":{"references":[{"attributes":{},"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3046197e-a163-4805-9573-652507f99035","subtype":"Figure","type":"Plot"}},"id":"f8623eb8-f68f-4772-86b9-4a2eed96aaf4","type":"HelpTool"},{"attributes":{"callback":null},"id":"9af6ccc6-3459-44e3-9daf-2247ea002d4f","type":"DataRange1d"},{"attributes":{"plot":{"id":"5f7a9bcd-a2e4-4e60-8705-fbc21f08128b","subtype":"Figure","type":"Plot"}},"id":"0ab5a2cb-d37b-4b5a-bc04-44b0d2abd626","type":"ResetTool"},{"attributes":{"formatter":{"id":"9b86f30c-8baf-4715-9337-138e2cd6183d","type":"BasicTickFormatter"},"plot":{"id":"03c4b73f-c0ec-434e-b4f2-6414d404f08c","subtype":"Figure","type":"Plot"},"ticker":{"id":"1dbc3058-4057-4640-aa7e-3889dc341f4c","type":"BasicTicker"}},"id":"beec01d5-6355-405d-8078-8c73ce283342","type":"LinearAxis"},{"attributes":{},"id":"a7b799da-48ac-444f-964e-245fdad251cf","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"b289f8d3-ae1d-49fc-9dcf-f948bad425ca","type":"BoxAnnotation"},"plot":{"id":"37e1a327-cbfe-4c1f-8969-370168ad9a7c","subtype":"Figure","type":"Plot"}},"id":"85f6509c-e34f-44a5-b9ef-b2af73a0bd4d","type":"BoxZoomTool"},{"attributes":{},"id":"782c5a55-eff7-4fc6-828e-62aa6e9504b8","type":"BasicTickFormatter"},{"attributes":{},"id":"1e6d640b-f39f-4e5e-802a-d4928db6ca5c","type":"ToolEvents"},{"attributes":{"plot":{"id":"2387f3a4-cc69-4bbc-9a6f-09f3dadad020","subtype":"Figure","type":"Plot"}},"id":"29181da0-023f-4c3d-b4f4-e8dac62eef1c","type":"ResetTool"},{"attributes":{"formatter":{"id":"a5bcafda-39b2-42b0-9993-066de8736c39","type":"BasicTickFormatter"},"plot":{"id":"c70fbdc1-6ec0-4af5-831a-faa7908e19ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf8b6649-e7b8-41f1-b2af-328e108922bd","type":"BasicTicker"}},"id":"201755dd-0b4f-430b-9988-ca3a7598330b","type":"LinearAxis"},{"attributes":{"plot":{"id":"aa116af7-068b-4fd6-8a1d-c6979addcaaf","subtype":"Figure","type":"Plot"},"ticker":{"id":"deb0f25d-1651-4d06-a211-536aa1cc47fa","type":"BasicTicker"}},"id":"5acbf516-1aff-4200-81fa-165d4b428a14","type":"Grid"},{"attributes":{"overlay":{"id":"1ac20f6a-8cdb-4d00-a472-6c905c01215e","type":"BoxAnnotation"},"plot":{"id":"87596c3e-f605-4ab2-9020-292a6d3e8558","subtype":"Figure","type":"Plot"}},"id":"e3020a6c-5fb8-4260-bd92-e911d191f0e5","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cf880c01-7498-4b7f-926c-7185c7813af2","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"a742695e-7b86-495b-80ef-4761e46b3416","type":"ColumnDataSource"},"glyph":{"id":"f473bad9-3dad-4ccf-896e-0aa761e6e554","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"884abaf3-afbf-4658-a51d-97efb14f07b5","type":"Text"},"selection_glyph":null},"id":"b8dc8a30-dae9-4289-9e12-f48cc4346d46","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"4aefa920-dff6-4deb-9448-6cc0bbe1128b","type":"ColumnDataSource"},"glyph":{"id":"bddde9f9-d73c-41a6-bd93-95c7de10e7c6","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"487f1a6a-193c-483e-a7a3-f92474c60e50","type":"Text"},"selection_glyph":null},"id":"3be9f0d5-bd37-4aa1-a188-0247642b3256","type":"GlyphRenderer"},{"attributes":{},"id":"74188be7-c5ae-4402-9d8f-db9d316efa9c","type":"BasicTicker"},{"attributes":{},"id":"2d1e3612-af95-4701-ba4d-529dd9010d7d","type":"ToolEvents"},{"attributes":{},"id":"e88a36bf-b619-4c85-b873-9eb88f872206","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["text","x","y"],"data":{"text":["pacwoman","spooky","toc-man","spunky","tim","orson","noname","pinky","blinky","clyde","inky"],"x":[0.5000000000000001,-0.4999999 ...

# %%
# source http://bokeh.pydata.org/en/0.11.1/docs/user_guide/geo.html
anchor_lat = 49.028404  #degrees
anchor_long = 12.062200 #degrees
anchor_point = np.array([anchor_long, anchor_lat])
size_unit = 40 # edge length in meters
def point_to_coordinates(anchor_point, size_unit, point):
    r_earth = 6371000 # meters    
    u_earth = 2*math.pi*r_earth
    scale_lat = 360/u_earth*size_unit
    anchor_lat = anchor_point[1] # longitudinal scaling depends on lateral position on earth 
    scale_long = scale_lat/math.cos(math.radians(anchor_lat)) 
    scale_vec = np.array([scale_long, scale_lat])
    return point*scale_vec+anchor_point

# test conversion
np.set_printoptions(precision=6)
test_points = construct_n_edge(11)
test_coords = []
new_point = anchor_point
for point in test_points:
    old_point = new_point
    new_point = point_to_coordinates(anchor_point, size_unit, point)
    test_coords.append(new_point)
    print("converting", point, new_point, new_point-old_point)
    # print("lat, long scaling", scale_lat, scale_long)
# Out:
# converting [ 0.841254  0.540641] [ 12.062662  49.028598] [ 0.000462  0.000194]
# converting [ 0.415415  0.909632] [ 12.062428  49.028731] [-0.000234  0.000133]
# converting [-0.142315  0.989821] [ 12.062122  49.02876 ] [-0.000306  0.000029]
# converting [-0.654861  0.75575 ] [ 12.061841  49.028676] [-0.000281 -0.000084]
# converting [-0.959493  0.281733] [ 12.061674  49.028505] [-0.000167 -0.000171]
# converting [-0.959493 -0.281733] [ 12.061674  49.028303] [ 0.       -0.000203]
# converting [-0.654861 -0.75575 ] [ 12.061841  49.028132] [ 0.000167 -0.000171]
# converting [-0.142315 -0.989821] [ 12.062122  49.028048] [ 0.000281 -0.000084]
# converting [ 0.415415 -0.909632] [ 12.062428  49.028077] [ 0.000306  0.000029]
# converting [ 0.841254 -0.540641] [ 12.062662  49.02821 ] [ 0.000234  0.000133]
# converting [ 1. -0.] [ 12.062749  49.028404] [ 0.000087  0.000194]

# %%
def show_points_on_map(anchor_point, list_of_points):
    
    map_options = GMapOptions(lat=anchor_point[1], lng=anchor_point[0], map_type="roadmap", zoom=18)

    plot = GMapPlot(
        x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, title="Regensburg"
    )

    # make list out of vectors for plotting
    x_points = []
    y_points = []
    for vec in list_of_points:
        x_points.append(vec[0])
        y_points.append(vec[1])
        
    source = ColumnDataSource(
        data=dict(
            lon=x_points,
            lat=y_points,
        )
    )

    circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
    plot.add_glyph(source, circle)
    
    plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
    # output_file("gmap_plot.html")

    show(plot)
  
show_points_on_map(anchor_point, test_coords)
# Out:
#     <div class="plotdiv" id="2ed9d364-e52e-4527-9cb5-29b0b03581ba"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2ed9d364-e52e-4527-9cb5-29b0b03581ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2ed9d364-e52e-4527-9cb5-29b0b03581ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9c04275f-20df-47eb-90a1-02527eca5b3c":{"roots":{"references":[{"attributes":{"callback":null},"id":"dc5465a0-5c23-48a4-b057-95527999c380","type":"DataRange1d"},{"attributes":{"plot":{"id":"d6653be8-8d6b-4db1-b0e1-ccdae1346d5a","type":"GMapPlot"}},"id":"8809cce4-ed47-4eca-b2be-b6af36378d2c","type":"PanTool"},{"attributes":{"callback":null,"overlay":{"id":"6db66c42-dd80-47f4-a275-ee84aded52d9","type":"BoxAnnotation"},"plot":{"id":"d6653be8-8d6b-4db1-b0e1-ccdae1346d5a","type":"GMapPlot"}},"id":"e0427eed-799e-445a-9083-aeef7eb0d85a","type":"BoxSelectTool"},{"attributes":{"callback":null},"id":"cba2de12-20df-4262-aa93-16f53a42d085","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["lon","lat"],"data":{"lat":[49.028598483987274,49.028731220682744,49.02876006712348,49.02867586476835,49.02850534727018,49.02830265272982,49.02813213523165,49.028047932876525,49.02807677931726,49.02820951601273,49.028404],"lon":[12.062661537294156,12.06242790932052,12.06212192174795,12.06184072346873,12.061673592949663,12.061673592949663,12.06184072346873,12.06212192174795,12.06242790932052,12.062661537294156,12.062748630437964]}},"id":"59a38189-520e-4b4d-9aa3-6fb375fe0889","type":"ColumnDataSource"},{"attributes":{},"id":"36a18491-db4c-435f-9c6a-8cd74191edd8","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6db66c42-dd80-47f4-a275-ee84aded52d9","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"86e22d18-f905-40f0-a940-920d81da268c","type":"Circle"},{"attributes":{"data_source":{"id":"59a38189-520e-4b4d-9aa3-6fb375fe0889","type":"ColumnDataSource"},"glyph":{"id":"86e22d18-f905-40f0-a940-920d81da268c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cf78760f-185e-44a3-9811-e517f2754685","type":"GlyphRenderer"},{"attributes":{"map_options":{"lat":49.028404,"lng":12.0622,"map_type":"roadmap","zoom":18},"renderers":[{"id":"cf78760f-185e-44a3-9811-e517f2754685","type":"GlyphRenderer"},{"id":"6db66c42-dd80-47f4-a275-ee84aded52d9","type":"BoxAnnotation"}],"title":"Regensburg","tool_events":{"id":"36a18491-db4c-435f-9c6a-8cd74191edd8","type":"ToolEvents"},"tools":[{"id":"8809cce4-ed47-4eca-b2be-b6af36378d2c","type":"PanTool"},{"id":"70eb6fb9-4faf-4a39-a8a9-069a8fcc5a6f","type":"WheelZoomTool"},{"id":"e0427eed-799e-445a-9083-aeef7eb0d85a","type":"BoxSelectTool"}],"x_range":{"id":"cba2de12-20df-4262-aa93-16f53a42d085","type":"DataRange1d"},"y_range":{"id":"dc5465a0-5c23-48a4-b057-95527999c380","type":"DataRange1d"}},"id":"d6653be8-8d6b-4db1-b0e1-ccdae1346d5a","type":"GMapPlot"},{"attributes":{"plot":{"id":"d6653be8-8d6b-4db1-b0e1-ccdae1346d5a","type":"GMapPlot"}},"id":"70eb6fb9-4faf-4a39-a8a9-069a8fcc5a6f","type":"WheelZoomTool"}],"root_ids":["d6653be8-8d6b-4db1-b0e1-ccdae1346d5a"]},"title":"Bokeh Application","version":"0.11.1"}};
#             var render_items = [{"docid":"9c04275f-20df-47eb-90a1-02527eca5b3c","elementid":"2ed9d364-e52e-4527-9cb5-29b0b03581ba","modelid":"d6653be8-8d6b-4db1-b0e1-ccdae1346d5a","notebook_comms_target":"629205b6-959b-416c-8f97-2f78b8c93e03"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
"""
uci set gluon-node-info.@location[0].latitude=53.834470
uci set gluon-node-info.@location[0].longitude=10.702518
uci commit gluon-node-info
/etc/init.d/alfred restart
"""
def assign_coordinates_routers(names, koordinates):
    ssh_str_lat = "uci set gluon-node-info.@location[0].latitude="
    ssh_str_lon = "uci set gluon-node-info.@location[0].longitude="
    ssh_str_commit = "uci commit gluon-node-info"
    ssh_srt_restart = "/etc/init.d/alfred restart"    
    
    output_list = []
    for i,name in enumerate(router_names):
        output_list.append(name)
        lat = str(koordinates[i][1])
        lon = str(koordinates[i][0])
        output_list.append(ssh_str_lat + str(lat))
        output_list.append(ssh_str_lon + str(lon))
        output_list.append(ssh_str_commit)
        output_list.append(ssh_srt_restart)
    
    return output_list
        
output_list = assign_coordinates_routers(router_names, test_coords) 
for line in output_list: print(line)
# Out:
# pacwoman
# uci set gluon-node-info.@location[0].latitude=49.028598484
# uci set gluon-node-info.@location[0].longitude=12.0626615373
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# spooky
# uci set gluon-node-info.@location[0].latitude=49.0287312207
# uci set gluon-node-info.@location[0].longitude=12.0624279093
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# toc-man
# uci set gluon-node-info.@location[0].latitude=49.0287600671
# uci set gluon-node-info.@location[0].longitude=12.0621219217
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# spunky
# uci set gluon-node-info.@location[0].latitude=49.0286758648
# uci set gluon-node-info.@location[0].longitude=12.0618407235
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# tim
# uci set gluon-node-info.@location[0].latitude=49.0285053473
# uci set gluon-node-info.@location[0].longitude=12.0616735929
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# orson
# uci set gluon-node-info.@location[0].latitude=49.0283026527
# uci set gluon-node-info.@location[0].longitude=12.0616735929
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# noname
# uci set gluon-node-info.@location[0].latitude=49.0281321352
# uci set gluon-node-info.@location[0].longitude=12.0618407235
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# pinky
# uci set gluon-node-info.@location[0].latitude=49.0280479329
# uci set gluon-node-info.@location[0].longitude=12.0621219217
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# blinky
# uci set gluon-node-info.@location[0].latitude=49.0280767793
# uci set gluon-node-info.@location[0].longitude=12.0624279093
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# clyde
# uci set gluon-node-info.@location[0].latitude=49.028209516
# uci set gluon-node-info.@location[0].longitude=12.0626615373
# uci commit gluon-node-info
# /etc/init.d/alfred restart
# inky
# uci set gluon-node-info.@location[0].latitude=49.028404
# uci set gluon-node-info.@location[0].longitude=12.0627486304
# uci commit gluon-node-info
# /etc/init.d/alfred restart
