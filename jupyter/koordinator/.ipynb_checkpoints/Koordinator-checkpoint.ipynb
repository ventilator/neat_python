# %%
import numpy as np
import math
np.set_printoptions(precision=3)
# prints _very_ small numbers (floating point errors)as 0
np.set_printoptions(suppress=True) 

# for plotting
from ipywidgets import interact
from bokeh.io import push_notebook
from bokeh.plotting import figure, show, output_notebook
# output_notebook()

def construct_n_edge(n):
    startpoint = np.array([0,0])
   
    unit_vec = np.array([1,0])
    angle = 2*math.pi / n
    rotation_matrix = np.array([[math.cos(angle), -math.sin(angle)], 
                               [math.sin(angle),  math.cos(angle)]])

    # built n-edge
    n_edge = []
    rotated_vector = unit_vec
    for i in range(n):
        rotated_vector = rotation_matrix.dot(rotated_vector)
        n_edge.append(rotated_vector)

    return n_edge


n = 4 #number of corners of the n-edge
for n in range(3,6):
    n_edge = construct_n_edge(n)  
    print(n,"-edge:")
    for vec in n_edge:
        print(vec)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e51871c7-73fd-4170-ab1f-f7f709176998">Loading BokehJS ...</span>
#     </div>
# 3 -edge:
# [-0.5    0.866]
# [-0.5   -0.866]
# [ 1. -0.]
# 4 -edge:
# [ 0.  1.]
# [-1.  0.]
# [-0. -1.]
# [ 1. -0.]
# 5 -edge:
# [ 0.309  0.951]
# [-0.809  0.588]
# [-0.809 -0.588]
# [ 0.309 -0.951]
# [ 1. -0.]

# %%
output_notebook()
def plot_n_edge(n_edge):
    x = []
    y = []
    # append first vector after lat to close the circle (plotting detail)
    n_edge.append(n_edge[0])
    for vec in n_edge:
        x.append(vec[0])
        y.append(vec[1])
        
    def plot(x,y): 
        p = figure(title="dots", plot_height=300, plot_width=300)
        r = p.line(x, y, color="#2222aa", line_width=3)
        show(p)
        
    plot(x,y)    
        
for n in range(3,6):
    n_edge = construct_n_edge(n)  
    plot_n_edge(n_edge)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8b964cb1-b3ea-4d78-abe0-c1e60fd60dfa">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="ca0a26db-6bb4-4afa-adfc-76792d3e6b0a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ca0a26db-6bb4-4afa-adfc-76792d3e6b0a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ca0a26db-6bb4-4afa-adfc-76792d3e6b0a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2aa99b2f-865a-4dfb-9b0c-86ac7919382e":{"roots":{"references":[{"attributes":{"plot":{"id":"01a9995d-d6ae-4852-a17d-05a3a1550af3","subtype":"Figure","type":"Plot"}},"id":"61f83d7a-8ab6-4716-98fa-e200cb92f7d8","type":"ResizeTool"},{"attributes":{"line_color":{"value":"#2222aa"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"86e07c64-6504-4f24-8a74-77fb94b15762","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"66f34d5d-5acc-4954-89a0-7e62d9507b1d","type":"Line"},{"attributes":{"plot":{"id":"01a9995d-d6ae-4852-a17d-05a3a1550af3","subtype":"Figure","type":"Plot"}},"id":"efe279bc-582d-4411-b48f-972d6d55facb","type":"ResetTool"},{"attributes":{"below":[{"id":"ab2c50b5-1fe2-4a27-a28f-e0f35f6714b3","type":"LinearAxis"}],"left":[{"id":"c81022b5-5299-4f74-ae20-3ab726ad3e8f","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"ab2c50b5-1fe2-4a27-a28f-e0f35f6714b3","type":"LinearAxis"},{"id":"25c747fc-9c36-478e-a635-f83e5240a684","type":"Grid"},{"id":"c81022b5-5299-4f74-ae20-3ab726ad3e8f","type":"LinearAxis"},{"id":"1cac605e-1293-4cdd-b9c9-77efd0c8c5cc","type":"Grid"},{"id":"04a2da5d-5aaf-4746-ba96-d0f1ff5e2a6d","type":"BoxAnnotation"},{"id":"cc1298e0-0fb8-4321-8230-d20ea06ec263","type":"GlyphRenderer"}],"title":"dots","tool_events":{"id":"fef3952a-369b-4874-a858-571ae1ffd51c","type":"ToolEvents"},"tools":[{"id":"df68d6ee-e6aa-44a6-891f-40fc192abf2c","type":"PanTool"},{"id":"6768c4c9-5e35-4dbd-bd5a-b45fe8013ae6","type":"WheelZoomTool"},{"id":"4a57e3d1-d0c1-4bbf-a53c-01f4e0710955","type":"BoxZoomTool"},{"id":"c597e21c-f4d8-4391-a71d-c9bc6028eeec","type":"PreviewSaveTool"},{"id":"bcdff15e-c8cf-4399-9bba-e043d77001c2","type":"ResizeTool"},{"id":"7752ad2a-b3de-4f79-89d5-99e625b7b444","type":"ResetTool"},{"id":"f3e49d19-c969-49d8-8d60-4181b1a816a6","type":"HelpTool"}],"x_range":{"id":"a9afcbb0-8c44-46f9-9abe-0f5d0a796949","type":"DataRange1d"},"y_range":{"id":"7bda3235-b493-4e67-b79c-59c09093e737","type":"DataRange1d"}},"id":"b6fd3737-35dd-4398-9886-b1c19690bf5f","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.4999999999999998,-0.5000000000000003,0.9999999999999998,-0.4999999999999998],"y":[0.8660254037844387,-0.8660254037844384,-6.106226635438361e-16,0.8660254037844387]}},"id":"1f10c15d-b33c-440c-b8ad-9c61b6c7ff3e","type":"ColumnDataSource"},{"attributes":{},"id":"6c8fc762-4c34-4850-85f8-4d0c9e5c1928","type":"BasicTicker"},{"attributes":{"overlay":{"id":"ba2482d7-eff5-47c2-9650-08c71a507820","type":"BoxAnnotation"},"plot":{"id":"59e52596-b62e-4edb-917e-fc5801ef9ff6","subtype":"Figure","type":"Plot"}},"id":"c0e771d4-6219-45e2-a1aa-171f3b25ef86","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"46351c7c-ddbb-45c0-91b9-3ad893fffdcf","type":"DataRange1d"},{"attributes":{"callback":null},"id":"4eace798-02e8-47f4-86d2-0c14f24c41ff","type":"DataRange1d"},{"attributes":{"formatter":{"id":"e0e45cf5-d10e-487b-98ce-05f184b619b8","type":"BasicTickFormatter"},"plot":{"id":"59e52596-b62e-4edb-917e-fc5801ef9ff6","subtype":"Figure","type":"Plot"},"ticker":{"id":"860449af-6206-4cf4-9800-698ae81721a4","type":"BasicTicker"}},"id":"9a7d1ae1-d783-4ee9-a695-6bf4065bb306","type":"LinearAxis"},{"attributes":{"plot":{"id":"a62b8f8a-56cb-4135-bbee-198108508721","subtype":"Figure","type":"Plot"},"ticker":{"id":"d3e69e23-984f-483a-a1c6-e6a6a08d06bf","type":"BasicTicker"}},"id":"1102d37b-ec7a-4a24-9ba9-7a17c19342ad","type":"Grid"},{"attributes":{"callback":null},"id":"15780542-eef4-4137-91d7-4e93ae48e097","type":"DataRange1d"},{"attributes":{"plot":{"id":"f93b2130-bcc4-43f1-85f5-55e10bd8b7c2","subtype":"Figure","type":"Plot"},"ticker":{"id":"aa9717e5-dc45-4f17-95e6-fda6b35d3655","type":"BasicTicker"}},"id":"a8fb8e6f-cd59-4f93-9a34-5936dde8526b","type":"Grid"},{"attributes":{"formatter":{"id":"338b127c-38b6-4bd6-9575-2b875691 ...
#     <div class="plotdiv" id="e7041aa6-41e6-4a51-9ba5-7090d2e4342f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
yphRenderer"}],"title":"dots","tool_events":{"id":"fef3952a-369b-4874-a858-571ae1ffd51c","type":"ToolEvents"},"tools":[{"id":"df68d6ee-e6aa-44a6-891f-40fc192abf2c","type":"PanTool"},{"id":"6768c4c9-5e35-4dbd-bd5a-b45fe8013ae6","type":"WheelZoomTool"},{"id":"4a57e3d1-d0c1-4bbf-a53c-01f4e0710955","type":"BoxZoomTool"},{"id":"c597e21c-f4d8-4391-a71d-c9bc6028eeec","type":"PreviewSaveTool"},{"id":"bcdff15e-c8cf-4399-9bba-e043d77001c2","type":"ResizeTool"},{"id":"7752ad2a-b3de-4f79-89d5-99e625b7b444","type":"ResetTool"},{"id":"f3e49d19-c969-49d8-8d60-4181b1a816a6","type":"HelpTool"}],"x_range":{"id":"a9afcbb0-8c44-46f9-9abe-0f5d0a796949","type":"DataRange1d"},"y_range":{"id":"7bda3235-b493-4e67-b79c-59c09093e737","type":"DataRange1d"}},"id":"b6fd3737-35dd-4398-9886-b1c19690bf5f","subtype":"Figure","type":"Plot"},{"attributes":{"below":[{"id":"b38c35bf-86b2-4776-8383-e80330096be6","type":"LinearAxis"}],"left":[{"id":"3235711b-d08b-4684-b11e-a2a3f829fdfe","type":"LinearAxis"}],"plot_height":300,"plot_width":300,"renderers":[{"id":"b38c35bf-86b2-4776-8383-e80330096be6","type":"LinearAxis"},{"id":"aa4b3361-5cc3-424a-9aa4-157d26bc50ba","type":"Grid"},{"id":"3235711b-d08b-4684-b11e-a2a3f829fdfe","type":"LinearAxis"},{"id":"104fe946-9fad-4794-b675-77ae68aebe70","type":"Grid"},{"id":"e546fec5-9db9-41a8-ac36-4832946c4ae3","type":"BoxAnnotation"},{"id":"80c8eef1-c183-4ed6-9a35-2701de6b3b0d","type":"GlyphRenderer"}],"title":"dots","tool_events":{"id":"5a639e8f-609a-4aa7-8bd8-bf8481bac031","type":"ToolEvents"},"tools":[{"id":"2c836305-dc9a-4913-a5de-14b838bade6c","type":"PanTool"},{"id":"675c5032-2b97-4345-a890-04a63fdb999f","type":"WheelZoomTool"},{"id":"208314cc-c571-4685-8268-7f5275a8c39f","type":"BoxZoomTool"},{"id":"7c3a9885-cc09-4778-8aa8-d9592e771b63","type":"PreviewSaveTool"},{"id":"e09534b2-f1b4-40c7-81d8-e109ccf2e28b","type":"ResizeTool"},{"id":"3255f6e4-fac6-42f3-abae-92a504da6320","type":"ResetTool"},{"id":"70f6491f-6e23-41b2-a478-966bcb720e55","type":"HelpTool"}],"x_range":{"id":"e78d750e-1f07-46d3-8a13-f4267c5feaba","type":"DataRange1d"},"y_range":{"id":"b3b9064a-de07-4302-9e6c-e3835b317855","type":"DataRange1d"}},"id":"7c0d129b-a49d-47e6-8744-ac0e453f6cd0","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.4999999999999998,-0.5000000000000003,0.9999999999999998,-0.4999999999999998],"y":[0.8660254037844387,-0.8660254037844384,-6.106226635438361e-16,0.8660254037844387]}},"id":"1f10c15d-b33c-440c-b8ad-9c61b6c7ff3e","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"65d1dc6d-3dce-48fe-b5d4-89b14929471f","type":"Basic ...

# %%
# maybe read this http://bokeh.pydata.org/en/0.11.1/docs/user_guide/geo.html
